# %% [markdown]
# # Python Medium & Advanced Practice
#
# Practice notebook focused on writing Python yourself. Try each exercise before checking the hints.

# %% [markdown]
# ## Part 1 — Medium Python

# %%
# Exercise 1: Count frequencies
# Given a list of numbers, create a dictionary containing how many
# times each number appears.

numbers = [2, 4, 2, 7, 4, 2, 9, 7, 7, 4]

# Your code here

# %%
# Exercise 2: Remove duplicates without using set()

numbers = [1, 2, 2, 3, 4, 3, 5, 1, 6, 5]

# Your code here

# %%
# Exercise 3: Find the second largest number
# Do not use sorted() or sort().

numbers = [10, 45, 23, 89, 12, 67, 89, 34]

# Your code here

# %%
# Exercise 4: Word frequency
# Count how many times each word occurs, ignoring uppercase/lowercase differences.

text = "Python is easy and Python is powerful and easy to learn"

# Your code here

# %%
# Exercise 5: Find common elements
# Return the common values between two lists without using set intersection.

list_a = [1, 2, 3, 4, 5, 6]
list_b = [4, 5, 6, 7, 8, 9]

# Your code here

# %%
# Exercise 6: Lambda + map/filter
# Create a list containing the squares of only the even numbers.

numbers = list(range(1, 21))

# Your code here

# %%
# Exercise 7: Sort dictionaries
# Sort students by marks from highest to lowest.

students = [
    {"name": "Alice", "marks": 82},
    {"name": "Bob", "marks": 95},
    {"name": "Charlie", "marks": 74},
    {"name": "David", "marks": 88},
]

# Your code here

# %%
# Exercise 8: Function with *args
# Write a function that accepts any number of numbers and returns:
# total, average, minimum, and maximum.

# Your code here

# %%
# Exercise 9: Recursion
# Write a recursive function that calculates factorial.

# Your code here

# %%
# Exercise 10: Simple bank account
# Create a BankAccount class with deposit(), withdraw(), and get_balance().
# Prevent withdrawals when the balance is insufficient.

# Your code here

# %% [markdown]
# ## Part 2 — Advanced Python

# %%
# Exercise 11: Custom iterator
# Create an iterator that returns numbers from 1 to n.

# Your code here

# %%
# Exercise 12: Generator
# Write a generator that yields Fibonacci numbers indefinitely.
# Use next() to retrieve the first 10 values.

# Your code here

# %%
# Exercise 13: Decorator
# Create a decorator called @timer that prints how long a function takes to run.

import time

# Your code here

# %%
# Exercise 14: Decorator for logging
# Create a decorator that prints the function name and its arguments
# every time the function is called.

# Your code here

# %%
# Exercise 15: Context manager
# Create your own context manager that prints:
# "Starting" when entering the with block and "Finished" when leaving it.

# Your code here

# %%
# Exercise 16: Dataclass
# Create a Student dataclass containing name, age, course, and marks.
# Add a method that returns whether the student passed (marks >= 40).

from dataclasses import dataclass

# Your code here

# %%
# Exercise 17: Type hints
# Write a function using type hints that accepts a list of integers
# and returns a dictionary containing min, max, average, and total.

# Your code here

# %%
# Exercise 18: Custom exception
# Create an InsufficientBalanceError exception and use it in BankAccount.

# Your code here

# %%
# Exercise 19: JSON data processing
# Convert the following Python dictionary to JSON and then load it back.
# After loading it, print all users whose age is >= 18.

import json

users = {
    "users": [
        {"name": "Alice", "age": 21},
        {"name": "Bob", "age": 16},
        {"name": "Charlie", "age": 25},
    ]
}

# Your code here

# %%
# Exercise 20: Mini project — Inventory Manager
            # 1. Adding products
# 2. Removing products
# 3. Updating quantity
# 4. Finding a product by name
# 5. Calculating total inventory value
# 6. Displaying products sorted by price

# Your code here

# %% [markdown]
# ## Challenge Projects
#
# 1. **CLI Expense Tracker** — add, delete, list, and summarize expenses using a JSON file.
# 2. **Student Management System** — CRUD operations with classes and file persistence.
# 3. **Log Analyzer** — read a server log file and count errors, warnings, IP addresses, and request methods.
# 4. **URL Shortener Simulation** — create short IDs for URLs and store the mapping in a dictionary or JSON file.
# 5. **Banking System** — users, accounts, transfers, transaction history, custom exceptions, and persistence.
# 6. **Multithreading Practice** — download/simulate multiple tasks concurrently using `threading` or `concurrent.futures`.
# 7. **Async Practice** — create several `async` tasks and use `asyncio.gather()` to run them concurrently.

# %% [markdown]
# ## Topics to Master
#
# - List/dict/set comprehensions
# - `*args` and `**kwargs`
# - Lambda, `map()`, `filter()`, `sorted()`
# - Recursion
# - OOP and inheritance
# - Exceptions and custom exceptions
# - Iterators and generators
# - Decorators
# - Context managers
# - Dataclasses
# - Type hints
# - JSON and file handling
# - Modules and packages
# - `collections` and `itertools`
# - `threading` and `concurrent.futures`
# - `asyncio` and `async/await`
